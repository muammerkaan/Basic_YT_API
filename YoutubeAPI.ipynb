# %% [markdown]
# # Data Science Portfolio Project

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#Keys
API_KEY = "AIzaSyD6_KQf0qCKtCQ6p3UkrpGHUwVY5oPGfpg"
CHANNEL_ID = "UCW8Ews7tdKKkBT6GdtQaXvQ"

# %%
def get_video_details(video_id):

    #collecting view, like, dislike, comment counts
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    return view_count, like_count, comment_count

# %%
def get_videos(df):
    pageToken = ""
    while 1:
        url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

        response = requests.get(url).json()
        time.sleep(1) #give it a second before starting the for loop
        for video in response['items']:
            if video['id']['kind'] == "youtube#video":
                video_id = video['id']['videoId']
                video_title = video['snippet']['title']
                video_title = str(video_title).replace("&amp;","")
                upload_date = video['snippet']['publishedAt']
                upload_date = str(upload_date).split("T")[0]
                view_count, like_count, comment_count = get_video_details(video_id)

                df = df.append({'video_id':video_id,'video_title':video_title,
                                "upload_date":upload_date,"view_count":view_count,
                                "like_count":like_count,
                                "comment_count":comment_count},ignore_index=True)
        try:
            if response['nextPageToken'] != None: #if none, it means it reached the last page and break out of it
                pageToken = "pageToken=" + response['nextPageToken']

        except:
            break


    return df

# %%
#main

#build our dataframe
df2 = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"]) 

df2 = get_videos(df2)

# %%
df2
# Out:
#        video_id                                        video_title  \
# 0   JDOAcKTy9Mk  Top 5 Data Science Project Ideas in 2022 to St...
# 1   o8cFJmI50Dw  STRING_AGG Function to Solve Data Science Inte...
# 2   ggZzHnzYH1s  How To Use Python Window Functions | Solving A...
# 3   8zeLdtkY2CQ  Data Science Mock Interview | Salesforce SQL C...
# 4   tnoOz6MzTPg  Python cumsum() | Solving Python Optimization ...
# ..          ...                                                ...
# 86  UX4_IgagL9I  How to Use Google Colaboratory | Import a CSV ...
# 87  tDdo3FiWpgE   Interview Questions for SQL Joins and Subqueries
# 88  wW827gqxlRY                      SQL Job Interview Mistakes #2
# 89  xbc2GpGUXwc                      SQL Job Interview Mistakes #1
# 90  n6gM265zG68  SQL Query Interview Questions And Answers From...
#
#    upload_date view_count like_count comment_count
# 0   2022-08-18        624         52             5
# 1   2022-08-11       1016         43             2
# 2   2022-08-03       2253        102             6
# 3   2022-06-17       5402        156            22
# 4   2022-05-11       2362         77            10
# ..         ...        ...        ...           ...
# 86  2020-05-02       2249         12             2
# 87  2020-02-01       1665         26             0
# 88  2019-09-15       1119         21             0
# 89  2019-08-03       7998         73             1
# 90  2019-06-26      43102        561             8
#
# [91 rows x 6 columns]
